# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# 1. Load and clean data
df = pd.read_csv(r'C:\Users\admin\Desktop\HousingData.csv')  # Adjust your file path if needed
df = df.fillna(df.median())  # Fill missing values with median

# 2. Prepare data
X = df.drop('MEDV', axis=1)  # Features (independent variables)
y = df['MEDV']  # Target prices (dependent variable)

# 3. Train model
model = LinearRegression()
model.fit(X, y)

# 4. Make predictions
df['Predicted'] = model.predict(X)

# 5. Calculate accuracy (R² Score)
accuracy = r2_score(y, df['Predicted'])
print(f"Model Accuracy (R² Score): {accuracy:.2%}")  # Shows as percentage

# 6. Calculate MSE and RMSE
mse = mean_squared_error(y, df['Predicted'])
rmse = np.sqrt(mse)
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

# 7. Visualization 1: Scatter plot (Actual vs Predicted prices)
plt.figure(figsize=(10, 5))
plt.scatter(y, df['Predicted'], alpha=0.3, color='blue')
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--', linewidth=2)
plt.title('Actual Prices vs Predicted Prices')
plt.xlabel('Actual Price ($1000s)')
plt.ylabel('Predicted Price ($1000s)')
plt.grid(True)
plt.show()

# # 8. Visualization 2: Actual and Predicted prices in different colors
# plt.figure(figsize=(12, 6))
# plt.scatter(range(len(y)), y, color='red', label='Actual Price', alpha=0.7)
# plt.scatter(range(len(df['Predicted'])), df['Predicted'], color='blue', label='Predicted Price', alpha=0.7)

# plt.title('Actual vs Predicted Home Prices (Colored Comparison)')
# plt.xlabel('House Index')
# plt.ylabel('Price ($1000s)')
# plt.legend()
# plt.grid(True)
# plt.show()

# 9. Show sample predictions
print("\nSample Predictions (First 10 Houses):")
print(df[['MEDV', 'Predicted']].head(10))
# Out:
# Model Accuracy (R² Score): 73.20%
# Mean Squared Error (MSE): 22.621222992569745
# Root Mean Squared Error (RMSE): 4.76
# Sample Predictions (First 10 Houses):
#    MEDV  Predicted
# 0  24.0  30.236311
# 1  21.6  24.992692
# 2  34.7  30.623989
# 3  33.4  28.914599
# 4  36.2  25.455505
# 5  28.7  25.421249
# 6  22.9  23.034948
# 7  27.1  19.697854
# 8  16.5  12.077293
# 9  18.9  19.029225

# %% [raw]
# Parameter	 What it tells Matplotlib to do
# X points = [y.min(), y.max()]	Start at minimum actual price, go to maximum actual price (horizontally).
# Y points = [y.min(), y.max()]	Same start and end, but for vertical axis (predicted).
# 'r--'	Draw a red dashed line connecting these two points.
# linewidth=2	Make the line a little thick so it's easy to see.
