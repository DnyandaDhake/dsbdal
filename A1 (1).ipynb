# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.datasets import load_iris
# df=pd.read_csv(r'C:\Users\admin\Desktop\Iris.csv')
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['Species'] = [iris.target_names[i] for i in iris.target]
print(df.head(6))
print("\n\n STatistics for this dataset\n\n ",df.describe())

print("\n\nMissing values checking",df.isnull().sum())

print("datatype cheking",df.dtypes)
df['Species']=df['Species'].astype('category')
# df['Species']=df['Species'].cat.codes
print(df.head(6))
print("\n\n")
print(df.tail(6))
print("")

print("after check datatype",df.dtypes)

# scale=MinMaxScaler()
# df[['SepalLengthCm' ,'SepalWidthCm',  'PetalLengthCm',  'PetalWidthCm']]=scale.fit_transform(df[['SepalLengthCm' ,'SepalWidthCm',  'PetalLengthCm',  'PetalWidthCm']])
# print("\n\nafter scaling on 0-1")
# print(df.head())
scaler = MinMaxScaler()
df[df.columns[:-1]] = scaler.fit_transform(df[df.columns[:-1]])
print("\n\nafter scaling on 0-1")
print(df)


le=LabelEncoder()
df['species_encoded']=le.fit_transform(df['Species'])
print(df[['Species','species_encoded']].drop_duplicates())

df['Species'].replace(['Setosa', 'Virginica'], [0,1], inplace=True)
print(df)

# df = df.rename(columns={'Species': 'Flower_Type'})
# print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
#
#   Species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# 5  setosa
#
#
#  STatistics for this dataset
#
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
#
#
# Missing values checking sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Species              0
# dtype: int64
# datatype cheking sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# Species               object
# dtype: object
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
#
#   Species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# 5  setosa
#
#
#
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        Species
# 144  virginica
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# after check datatype sepal length (cm)     float64
# sepal width (cm)      float64
# petal length (cm)     float64
# petal width (cm)      float64
# Species              category
# dtype: object
#
#
# after scaling on 0-1
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0             0.222222          0.625000           0.067797          0.041667
# 1             0.166667          0.416667           0.067797          0.041667
# 2             0.111111          0.500000           0.050847          0.041667
# 3             0.083333          0.458333           0.084746          0.041667
# 4             0.194444          0.666667           0.067797          0.041667
# ..                 ...               ...                ...               ...
# 145           0.666667          0.416667           0.711864          0.916667
# 146           0.555556          0.208333           0.677966          0.750000
# 147           0.611111          0.416667           0.711864          0.791667
# 148           0.527778          0.583333           0.745763          0.916667
# 149           0.444444          0.416667           0.694915          0.708333
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]
#         Species  species_encoded
# 0        setosa                0
# 50   versicolor                1
# 100   virginica                2
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0             0.222222          0.625000           0.067797          0.041667
# 1             0.166667          0.416667           0.067797          0.041667
# 2             0.111111          0.500000           0.050847          0.041667
# 3             0.083333          0.458333           0.084746          0.041667
# 4             0.194444          0.666667           0.067797          0.041667
# ..                 ...               ...                ...               ...
# 145           0.666667          0.416667           0.711864          0.916667
# 146           0.555556          0.208333           0.677966          0.750000
# 147           0.611111          0.416667           0.711864          0.791667
# 148           0.527778          0.583333           0.745763          0.916667
# 149           0.444444          0.416667           0.694915          0.708333
#
#        Species  species_encoded
# 0       setosa                0
# 1       setosa                0
# 2       setosa                0
# 3       setosa                0
# 4       setosa                0
# ..         ...              ...
# 145  virginica                2
# 146  virginica                2
# 147  virginica                2
# 148  virginica                2
# 149  virginica                2
#
# [150 rows x 6 columns]
# C:\Users\admin\AppData\Local\Temp\ipykernel_14308\3249185686.py:38: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Species'].replace(['Setosa', 'Virginica'], [0,1], inplace=True)

# %%
 df = df.rename(columns={'Species': 'Flower_Type'})
 print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0           0.222222          0.625000           0.067797          0.041667
# 1           0.166667          0.416667           0.067797          0.041667
# 2           0.111111          0.500000           0.050847          0.041667
# 3           0.083333          0.458333           0.084746          0.041667
# 4           0.194444          0.666667           0.067797          0.041667
#
#   Flower_Type  species_encoded
# 0      setosa                0
# 1      setosa                0
# 2      setosa                0
# 3      setosa                0
# 4      setosa                0
